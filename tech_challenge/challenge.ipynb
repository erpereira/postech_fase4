# %% [markdown]
# ### 1. Importação de Bibliotecas e Carregamento de Dados

# %%
import pandas as pd
import matplo
# Carregando dataset 
df = pd.read_csv('https://raw.githubusercontent.com/erpereira/postech_fase4/refs/heads/main/data/Obesity.csv')

# Visualizando as primeiras linhas do dataset
#display(df.head())

# Visualizando informacoes sobre as features
#display(df.info())

# Realizando um resumo estatistico
#display(df.describe())

# %% [markdown]
# ### 2. Análise de Dados Faltantes e Duplicatas

# %%
# Verificando dados faltantes
print(df.isnull().sum())
print("\nPorcentagem de faltantes:\n", df.isnull().sum() / len(df) * 100)

# Visualizar faltantes
